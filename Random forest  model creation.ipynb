# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("Water_cleaned_final.csv")

# %%
dataset
# Out:
#     Household_ID  members   Daily_Water_Consumption_Liters  Temperature_C  \
# 0              1         2                             420           26.4
# 1              2         3                             510           27.1
# 2              3         4                             630           28.9
# 3              4         5                             720           30.2
# 4              5         3                             460           25.8
# ..           ...       ...                             ...            ...
# 95            96         6                             860           34.8
# 96            97         2                             380           24.8
# 97            98         4                             560           28.5
# 98            99         3                             490           26.4
# 99           100         5                             700           30.3
#
#     Humidity_percent water source  type  drinking_water_ use _Liters   \
# 0                 55          Municipal                            12
# 1                 60           Borewell                            15
# 2                 58          Municipal                            18
# 3                 62             Tanker                            20
# 4                 50           Borewell                            14
# ..               ...                ...                           ...
# 95                74           Borewell                            24
# 96                50             Tanker                            11
# 97                60          Municipal                            16
# 98                53           Borewell                            13
# 99                68           Borewell                            20
#
#     Appliance_Usage_Water_Liters Day_type
# 0                             65  weekday
# 1                             70  Weekday
# 2                             75  Weekend
# 3                             80  Weekday
# 4                             60  Weekday
# ..                           ...      ...
# 95                            75  Weekday
# 96                            65  Weekend
# 97                            80  Weekday
# 98                            70  Weekend
# 99                            75  Weekday
#
# [100 rows x 9 columns]

# %%
dataset.columns
# Out:
# Index(['Household_ID', 'members ', 'Daily_Water_Consumption_Liters',
#        'Temperature_C', 'Humidity_percent', 'water source  type',
#        'drinking_water_ use _Liters ', 'Appliance_Usage_Water_Liters',
#        'Day_type'],
#       dtype='object')

# %%
print(dataset.columns.tolist())
# Out:
# ['Household_ID', 'members ', 'Daily_Water_Consumption_Liters', 'Temperature_C', 'Humidity_percent', 'water source  type', 'drinking_water_ use _Liters ', 'Appliance_Usage_Water_Liters', 'Day_type']

# %%
independent = dataset[['Household_ID',
                       'members',
                       'Daily_Water_Consumption_Liters',
                       'Temperature_C',
                       'Humidity_percent',
                       'water source  type',
                       'drinking_water_ use _Liters',
                       'Appliance_Usage_Water_Liters',
                       'Day_type']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 independent = dataset[['Household_ID',
#       2                        'members',
#       3                        'Daily_Water_Consumption_Liters',
#       4                        'Temperature_C',
#       5                        'Humidity_percent',
#       6                        'water source  type',
#       7                        'drinking_water_ use _Liters',
#       8                        'Appliance_Usage_Water_Liters',
#       9                        'Day_type']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['members', 'drinking_water_ use _Liters'] not in index"
